# %%
import pandas as pd
import numpy as np

# %%
cluster=pd.read_csv("Cluster Weighting.csv")
matrix=pd.read_csv("Matrix Score.csv")
# user inputs will pull from database
user_inputs = pd.read_csv("user inputs from database.csv")

# get cluster from one or two questions
user_cluser = "Cluster 2"

print(matrix.head())

print(cluster.head())

print(user_inputs.head())
# Out:
#   Category Question  Question_Scale  Weight
# 0  resorts       Q1               1       0
# 1  resorts       Q1               2       1
# 2  resorts       Q1               3       1
# 3  resorts       Q1               4       1
# 4  resorts       Q1               5       1
#       Group Category     Cluser     Value
# 0  activity  resorts  Cluster 1  1.749976
# 1  activity  resorts  Cluster 2  2.708463
# 2  activity  resorts  Cluster 3  2.641268
# 3  activity  resorts  Cluster 4  2.214440
# 4  activity  beaches  Cluster 1  1.733534
#   Questions  Answer
# 0        Q1       1
# 1        Q2       3
# 2        Q3       2
# 3        Q4       4
# 4        Q5       5

# %%
# merge matrix with user answer 
user_scale = matrix.merge(user_inputs, left_on = 'Question', right_on='Questions')
user_scale.head()
# Out:
#   Category Question  Question_Scale  Weight Questions  Answer
# 0  resorts       Q1               1       0        Q1       1
# 1  resorts       Q1               2       1        Q1       1
# 2  resorts       Q1               3       1        Q1       1
# 3  resorts       Q1               4       1        Q1       1
# 4  resorts       Q1               5       1        Q1       1

# %%
# clean up the merge dataframe and filter out the values only for answers
user_scale = user_scale.loc[user_scale['Question_Scale'] == user_scale['Answer']]
user_scale
# Out:
#            Category Question  Question_Scale  Weight Questions  Answer
# 0           resorts       Q1               1       0        Q1       1
# 5          churches       Q1               1       1        Q1       1
# 10      dance-clubs       Q1               1       1        Q1       1
# 15    art-galleries       Q1               1       1        Q1       1
# 20         theatres       Q1               1       1        Q1       1
# ...             ...      ...             ...     ...       ...     ...
# 1076    restaurants      Q10               2       1       Q10       2
# 1081      pubs-bars      Q10               2       0       Q10       2
# 1086   burger-pizza      Q10               2       0       Q10       2
# 1091       bakeries      Q10               2       0       Q10       2
# 1096          cafes      Q10               2       1       Q10       2
#
# [220 rows x 6 columns]

# %%
user_scale_total = user_scale.groupby(['Category']).sum(['Value']).drop(columns = ['Question_Scale','Answer'])
user_scale_total
# Out:
#                 Weight
# Category
# art-galleries        5
# bakeries             2
# beaches              4
# beauty-spas          3
# burger-pizza         6
# cafes                5
# churches             8
# dance-clubs          7
# gardens              5
# gyms                 6
# juice-bars           5
# malls                6
# monuments            4
# museums              5
# parks                3
# pubs-bars            5
# resorts              5
# restaurants          8
# swimming-pools       6
# theatres             7
# view-points          4
# zoo                  6

# %%
# Merge Cluster with user_scale_total
user_final = cluster.loc[cluster['Cluser']== user_cluser]
user_final_Cat = user_final.merge(user_scale_total, how = "left", left_on = "Category", right_on= "Category")
user_final_Cat['Final_Score_per_Cat'] = user_final_Cat['Value'] * user_final_Cat['Weight']
# user_final_Cat['Total_Score__Cat'] = user_final_Cat.groupby('Group').sum(['Final_Score'])
# top_3 = user_final_Cat.loc[user_final_Cat.groupby('Group')["Final_Score"].idxmax()]
# top_3 = list(top_3["Category"])
top_3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_Score__Cat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\core\frame.py in _set_item_mgr(self, key, value)
#    3750         try:
# -> 3751             loc = self._info_axis.get_loc(key)
#    3752         except KeyError:
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#
# KeyError: 'Total_Score__Cat'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\EVENXU~1\AppData\Local\Temp/ipykernel_2016/1041697440.py in <module>
#       3 user_final_Cat = user_final.merge(user_scale_total, how = "left", left_on = "Category", right_on= "Category")
#       4 user_final_Cat['Final_Score_per_Cat'] = user_final_Cat['Value'] * user_final_Cat['Weight']
# ----> 5 user_final_Cat['Total_Score__Cat'] = user_final_Cat.groupby('Group').sum(['Final_Score'])
#       6 # top_3 = user_final_Cat.loc[user_final_Cat.groupby('Group')["Final_Score"].idxmax()]
#       7 # top_3 = list(top_3["Category"])
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    3740         # now align rows
#    3741         arraylike = _reindex_for_setitem(value, self.index)
# -> 3742         self._set_item_mgr(key, arraylike)
#    3743
#    3744     def _iset_item_mgr(self, loc: int | slice | np.ndarray, value) -> None:
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\core\frame.py in _set_item_mgr(self, key, value)
#    3752         except KeyError:
#    3753             # This item wasn't present, just insert at end
# -> 3754             self._mgr.insert(len(self._info_axis), key, value)
#    3755         else:
#    3756             self._iset_item_mgr(loc, value)
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value)
#    1160             value = ensure_block_shape(value, ndim=self.ndim)
#    1161
# -> 1162         block = new_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1163
#    1164         for blkno, count in _fast_count_smallints(self.blknos[loc:]):
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\core\internals\blocks.py in new_block(values, placement, ndim, klass)
#    1935
#    1936     values, _ = extract_pandas_array(values, None, ndim)
# -> 1937     check_ndim(values, placement, ndim)
#    1938
#    1939     if klass is None:
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\core\internals\blocks.py in check_ndim(values, placement, ndim)
#    1978         if len(placement) != len(values):
#    1979             raise ValueError(
# -> 1980                 f"Wrong number of items passed {len(values)}, "
#    1981                 f"placement implies {len(placement)}"
#    1982             )
#
# ValueError: Wrong number of items passed 3, placement implies 1

# %%
top_3_check = user_final_Cat.sort_values(['Group','Final_Score'],ascending = [True,False])
top_3_check
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\EVENXU~1\AppData\Local\Temp/ipykernel_2016/1244596639.py in <module>
# ----> 1 top_3_check = user_final_Cat.sort_values(['Group','Final_Score'],ascending = [True,False])
#       2 top_3_check
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6240         if len(by) > 1:
#    6241
# -> 6242             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6243
#    6244             # need to rewrap columns in Series to apply key function
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\core\frame.py in <listcomp>(.0)
#    6240         if len(by) > 1:
#    6241
# -> 6242             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6243
#    6244             # need to rewrap columns in Series to apply key function
#
# C:\DataUoT\Pandas\envs\pythondata\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'Final_Score'
