# %% [markdown]
# ## ROUGH DRAFT OF WORKING CODE TO COLLECT GOOGLE MAPS DATA

# %%
import urllib3
import json
import googlemaps

with open('GoogleMaps.txt') as f:
    lines = f.read()

#google_api = "AIzaSyDmVjy33FQzNmdNt8L4eu39gpHa58oF1no"
google_api = lines.split('\n', 1)[0]
first = lines.split('\n', 1)[0]
#url = 
#json_obj = urllib3.urlopen(url)

# %%
print(google_api)
# Out:
# AIzaSyDmVjy33FQzNmdNt8L4eu39gpHa58oF1no

# %%
# Run only once
pip install git+git://github.com/scrappy/scrappy@master
# Out:
# Collecting git+git://github.com/scrappy/scrappy@master
#   Cloning git://github.com/scrappy/scrappy (to revision master) to c:\users\bkuro\appdata\local\temp\pip-req-build-6sgad1kb
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\bkuro\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bkuro\anaconda3\lib\site-packages)
#   Running command git clone --filter=blob:none --quiet git://github.com/scrappy/scrappy 'C:\Users\bkuro\AppData\Local\Temp\pip-req-build-6sgad1kb'
#   fatal: remote error:
#     The unauthenticated git protocol on port 9418 is no longer supported.
#   Please see https://github.blog/2021-09-01-improving-git-protocol-security-github/ for more information.
#   error: subprocess-exited-with-error
#
#   git clone --filter=blob:none --quiet git://github.com/scrappy/scrappy 'C:\Users\bkuro\AppData\Local\Temp\pip-req-build-6sgad1kb' did not run successfully.
#   exit code: 128
#
#   See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# git clone --filter=blob:none --quiet git://github.com/scrappy/scrappy 'C:\Users\bkuro\AppData\Local\Temp\pip-req-build-6sgad1kb' did not run successfully.
# exit code: 128
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# WARNING: Ignoring invalid distribution -umpy (c:\users\bkuro\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bkuro\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bkuro\anaconda3\lib\site-packages)

# %%
map_client = googlemaps.Client(google_api)

# %%
dir(map_client)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_generate_auth_url',
#  '_get',
#  '_get_body',
#  '_request',
#  'base_url',
#  'channel',
#  'clear_experience_id',
#  'client_id',
#  'client_secret',
#  'directions',
#  'distance_matrix',
#  'elevation',
#  'elevation_along_path',
#  'find_place',
#  'geocode',
#  'geolocate',
#  'get_experience_id',
#  'key',
#  'nearest_roads',
#  'place',
#  'places',
#  'places_autocomplete',
#  'places_autocomplete_query',
#  'places_nearby',
#  'places_photo',
#  'queries_per_second',
#  'requests_kwargs',
#  'retry_over_query_limit',
#  'retry_timeout',
#  'reverse_geocode',
#  'sent_times',
#  'session',
#  'set_experience_id',
#  'snap_to_roads',
#  'snapped_speed_limits',
#  'speed_limits',
#  'static_map',
#  'timeout',
#  'timezone']

# %%
test_address = '1 market st, San Francisco, CA'
map_client.geocode(test_address)
# Out:
# [{'address_components': [{'long_name': '1',
#     'short_name': '1',
#     'types': ['street_number']},
#    {'long_name': 'Market Street',
#     'short_name': 'Market St',
#     'types': ['route']},
#    {'long_name': 'Financial District',
#     'short_name': 'Financial District',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'San Francisco',
#     'short_name': 'SF',
#     'types': ['locality', 'political']},
#    {'long_name': 'San Francisco County',
#     'short_name': 'San Francisco County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'California',
#     'short_name': 'CA',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '94105', 'short_name': '94105', 'types': ['postal_code']},
#    {'long_name': '1420',
#     'short_name': '1420',
#     'types': ['postal_code_suffix']}],
#   'formatted_address': '1 Market St, San Francisco, CA 94105, USA',
#   'geometry': {'location': {'lat': 37.7939877, 'lng': -122.39515},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.7955088802915,
#      'lng': -122.3937276697085},
#     'southwest': {'lat': 37.7928109197085, 'lng': -122.3964256302915}}},
#   'place_id': 'ChIJkXCsHWSAhYARsGBBQYcj-V0',
#   'plus_code': {'compound_code': 'QJV3+HW Financial District, San Francisco, CA',
#    'global_code': '849VQJV3+HW'},
#   'types': ['street_address']}]

# %%
from googleplaces import GooglePlaces, types, lang

google_places = GooglePlaces(google_api)

# You may prefer to use the text_search API, instead.
query_result = google_places.nearby_search(
        location='London, England', keyword='Fish and Chips',
        radius=20000, types=[types.TYPE_FOOD])
# If types param contains only 1 item the request to Google Places API
# will be send as type param to fullfil:
# http://googlegeodevelopers.blogspot.com.au/2016/02/changes-and-quality-improvements-in_16.html

if query_result.has_attributions:
    print(query_result.html_attributions)


for place in query_result.places:
    # Returned places from a query are place summaries.
    print(place.name)
    print (place.geo_location)
    print (place.place_id)

    # The following method has to make a further API call.
    place.get_details()
    # Referencing any of the attributes below, prior to making a call to
    # get_details() will raise a googleplaces.GooglePlacesAttributeError.
    print (place.details) # A dict matching the JSON response from Google.
    print (place.local_phone_number)
    print (place.international_phone_number)
    print (place.website)
    print (place.url)

    # Getting place photos

    for photo in place.photos:
        # 'maxheight' or 'maxwidth' is required
        photo.get(maxheight=500, maxwidth=500)
        # MIME-type, e.g. 'image/jpeg'
        photo.mimetype
        # Image URL
        photo.url
        # Original filename (optional)
        photo.filename
        # Raw image data
        photo.data


# Are there any additional pages of results?
if query_result.has_next_page_token:
    query_result_next_page = google_places.nearby_search(
            pagetoken=query_result.next_page_token)
# Out:
# The Mayfair Chippy
# {'lat': Decimal('51.5131605'), 'lng': Decimal('-0.1533195')}
# ChIJ6z7OljIFdkgRUDkQBqcNkEk
# {'address_components': [{'long_name': '14', 'short_name': '14', 'types': ['street_number']}, {'long_name': 'North Audley Street', 'short_name': 'N Audley St', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1K 6WE', 'short_name': 'W1K 6WE', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">14 North Audley Street</span>, <span class="locality">London</span> <span class="postal-code">W1K 6WE</span>, <span class="country-name">UK</span>', 'business_status': 'OPERATIONAL', 'formatted_address': '14 N Audley St, London W1K 6WE, UK', 'formatted_phone_number': '020 7741 2233', 'geometry': {'location': {'lat': Decimal('51.5131708'), 'lng': Decimal('-0.1532625')}, 'viewport': {'northeast': {'lat': Decimal('51.5145022802915'), 'lng': Decimal('-0.152011569708498')}, 'southwest': {'lat': Decimal('51.5118043197085'), 'lng': Decimal('-0.154709530291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'international_phone_number': '+44 20 7741 2233', 'name': 'The Mayfair Chippy', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day':
 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104152541875713997698">Laurence Robert</a>'], 'photo_reference': 'Aap_uEAXuH8bFWcqCFrly8oH90qN3It_h2jwaoGn90eDlIRUnl5lLzSia3tMZqgVOH30rnCL8cZlUtiapjuReU6Hu0BxiYgRl1Pb4gGXsMkPFBU87MKgsX66nZGag3XOBhJ8tUkqI5X-SWv8k19NuQOTWmi7ez-ZywsWQcaD3dFiQzTzDM0v', 'width': 3024}, {'height': 3648, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113024939979679601908">stefano pirondi</a>'], 'photo_reference': 'Aap_uEBOD8_B-FsLRjkz9O5HsW07byoVXJmUWgiLueCGxYp ...
# 020 7729 3178
# +44 20 7729 3178
# http://www.shoreditchfishnchips.co.uk/
# https://maps.google.com/?cid=12441701593850016595
# Windmill Fish Bar
# {'lat': Decimal('51.4873053'), 'lng': Decimal('-0.1120553')}
# ChIJryYw55MEdkgRzHT38gdwOP0
# {'address_components': [{'long_name': '211', 'short_name': '211', 'types': ['street_number']}, {'long_name': 'Kennington Lane', 'short_name': 'Kennington Ln', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SE11 5QS', 'short_name': 'SE11 5QS', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">211 Kennington Lane</span>, <span class="locality">London</span> <span class="postal-code">SE11 5QS</span>, <span class="country-name">UK</span>', 'business_status': 'OPERATIONAL', 'formatted_address': '211 Kennington Ln, London SE11 5QS, UK', 'formatted_phone_number': '020 7582 5754', 'geometry': {'location': {'lat': Decimal('51.4873053'), 'lng': Decimal('-0.1120553')}, 'viewport': {'northeast': {'lat': Decimal('51.4886929802915'), 'lng': Decimal('-0.110799919708498')}, 'southwest': {'lat': Decimal('51.4859950197085'), 'lng': Decimal('-0.113497880291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'international_phone_number': '+44 20 7582 5754', 'name': 'Windmill Fish Bar', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 1, 'time': '2100'}, 'open': {'day': 1, 'time': '1200'}}, {'close': {'day': 2, 'time': '2100'}, 'open': {'day': 2, 'time': '1200'}}, {'close': {'day': 3, 'time': '2100'}, 'open': {'day': 3, 'time': '1200'}}, {'close': {'day': 4, 'time': '2100'}, 'open': {'day': 4, 'time': '1200'}}, {'close': {'day': 5, 'time': '2100'}, 'open': {'day': 5, 'time': '1200'}}, {'close': {'day': 6, 'time': '2100'}, 'open': {'day': 6, 'time': '1200'}}], 'weekday_text': ['Monday: 12:00 – 9:00 PM', 'Tuesday: 12:00 – 9:00 PM', 'Wednesday: 12:00 – 9:00 PM', 'Thursday: 12:00 – 9:00 PM', 'Friday: 12:00 – 9:00 PM', 'Saturday: 12:00 – 9:00 PM', 'Sunday: Closed']}, 'photos': [{'height': 2905, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104771369170657206207">Joey Paysinger</a>'], 'photo_reference': 'Aap_uECQ4mQ8Oz7h5lIfCf0zjb_ZpLs8v6O6sZkGFrUXSTDryteULsOtTAAazI8dD_8F41wnesW0UAB59leGU4UCCA1UrO9FgBNJeJPrACXWLKB7Q8WJKcJMnDpM98l6XOZCCiFZ1FGRT6kBb6rqzS5RRBYvhbWEQIg3VcBq3N3JGjBAZcVA', 'width': 3873}, {'height': 880, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103163083773408260202">Windmill Fish Bar</a>'], 'photo_reference': 'Aap_uEDDCXpWuXHhQ54OwkDqFYwqKI-ZtpdI8vcIEN-ZECoJavZvdAWHk6Zv6GOOVtT1Grx97VOVoHTRDPLu8x9ULVVKKS5g2hCowK4lstZtppOLis3SS0upjhpIGuj_revJvjmnbQtjL4uqojlxPvZl_b350-kaKBLtFCQ98zfSktJFGd_f', 'width': 1280}, {'height': 3480, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110777772484987309158">Ed O&#39;Meara</a>'], 'photo_reference': 'Aap_uEAEvHf1Dp_1HR8Y8PmRNkzyAooNmjyYHuM7DcbSPoFUZ7WigeeKPaUdntrs0wfbF3J4Q0a9d5FWToKg2TbVA4x-GGAb7XtHkmectD3Ce2xhLJB7HFJgo2vqUJ7MKC7v48YWWro4Dagk9YtO_AVIFyboy9bMBiKbBVNb_U0abOuhUn2o', 'width': 4640}, {'height': 410, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103163083773408260202">Windmill Fish Bar</a>'], 'photo_reference': 'Aap_uEABxLDUnB1IVQF1u52LidpQ8kqGILd4pyGV8zcd9euXtOPXYML0Q-uiG0ldfq_MKJy4UUsw6bPDCnIRJTELsytxMf8tVPfWTu4dznSvxrLLNEjRkzFpAN6LmBXNci1nJXTTPUPi3E9V938RF7ESaAGrX0bfhw5GcNlCnMkDBqW-DNfu', 'width': 640}, {'height': 3000, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101806842887977896429">Carolina Bonafonte</a>'], 'photo_reference': 'Aap_uEDWvjbrUW8JBKFsJw-nCdoZWCsBXC52RK-gWLk10dtT-tns6GJ-C0sb3S-f_XGhMcOuXx5c43GFuAHuqRFsC7_dT1A9-wQ7QxINjloxBCkUP9fC4yZSbjs5hm1OArT4qJxPaOmzg7k66SLBLRLMX1cZz--ZXJS2 ...
# 020 7582 5754
# +44 20 7582 5754
# None
# https://maps.google.com/?cid=18246457069734950092
# Poppies Fish & Chips
# {'lat': Decimal('51.5202009'), 'lng': Decimal('-0.0740333')}
# ChIJX7eIgrYcdkgRJtmJIysIZVc
# {'address_components': [{'long_name': '6-8', 'short_name': '6-8', 'types': ['street_number']}, {'long_name': 'Hanbury Street', 'short_name': 'Hanbury St', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'E1 6QR', 'short_name': 'E1 6QR', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">6-8 Hanbury Street</span>, <span class="locality">London</span> <span class="postal-code">E1 6QR</span>, <span class="country-name">UK</span>', 'business_status': 'OPERATIONAL', 'formatted_address': '6-8 Hanbury St, London E1 6QR, UK', 'formatted_phone_number': '020 7247 0892', 'geometry': {'location': {'lat': Decimal('51.5202041'), 'lng': Decimal('-0.074035')}, 'viewport': {'northeast': {'lat': Decimal('51.5215973302915'), 'lng': Decimal('-0.07267721970849797')}, 'southwest': {'lat': Decimal('51.5188993697085'), 'lng': Decimal('-0.07537518029150203')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'international_phone_number': '+44 20 7247 0892', 'name': 'Poppies Fish & Chips', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 0, 'time': '2200'}, 'open': {'day': 0, 'time': '1100'}}, {'close': {'day': 1, 'time': '2200'}, 'open': {'day': 1, 'time': '1100'}}, {'close': {'day': 2, 'time': '2200'}, 'open': {'day': 2, 'time': '1100'}}, {'close': {'day': 3, 'time': '2200'}, 'open': {'day': 3, 'time': '1100'}}, {'close': {'day': 4, 'time': '2300'}, 'open': {'day': 4, 'time': '1100'}}, {'
 'types': ['postal_code']}], 'adr_address': '<span class="street-address">19 Fulham High Street</span>, <span class="locality">London</span> <span class="postal-code">SW6 3JH</span>, <span class="country-name">UK</span>', 'business_status': 'OPERATIONAL', 'formatted_address': '19 Fulham High St, London SW6 3JH, UK', 'formatted_phone_number': '020 7371 5555', 'geometry': {'location': {'lat': Decimal('51.470954'), 'lng': Decimal('-0.210788')}, 'viewport': {'northeast': {'lat': Decimal('51.4722733802915'), 'lng': Decimal('-0.209507669708498')}, 'southwest': {'lat': Decimal('51.46957541970851'), 'lng': Decimal('-0.212205630291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'international_phone_number': '+44 20 7371 5555', 'name': 'Fishers', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 0, 'time': '2200'}, 'open': {'day': 0, 'time': '1200'}}, {'close': {'day': 1, 'time': '2200'}, 'open': {'day': 1, 'time': '1200'}}, {'close': {'day': 2, 'time': '2200'}, 'open': {'day': 2, 'time': '1200'}}, {'close': {'day': 3, 'time': '2200'}, 'open': {'day': 3, 'time': '1200'}}, {'close': {'day': 4, 'time': '2200'}, 'open': {'day': 4, 'time': '1200'}}, {'close': {'day': 5, 'time': '2200'}, 'open': {'day': 5, 'time': '1200'}}, {'close': {'day': 6, 'time': '2200'}, 'open': {'day': 6, 'time': '1200'}}], 'weekday_text': ['Monday: 12:00 – 10:00 PM', 'Tuesday: 12:00 – 10:00 PM', 'Wednesday: 12:00 – 10:00 PM', 'Thursday: 12:00 – 10:00 PM', 'Friday: 12:00 – 10:00 PM', 'Saturday: 12:00 – 10:00 PM', 'Sunday: 12:00 – 10:00 PM']}, 'photos': [{'height': 1052, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107314984843688174769">Fishers</a>'], 'photo_reference': 'Aap_uEDNQlVr2qWYKMMwhb2c4N9W_i9YDAqDXdqfBZFinOMULzocIo4KPHGg9t9MFSJl5udvzniQeQ9civxrNW7y4-oQJ_n8SRqLS8RXJcUUfGdRIIbFh5uX3hASnHjkHNMZfpvEbAyEJJxvjZShSh2a4f4ZtvHD8-gvtgCcBsvnlj3g9mZS', 'width': 828}, {'height': 913, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107314984843688174769">Fishers</a>'], 'photo_reference': 'Aap_uEDXSXAqK8f30LdUpspAqtn3I7voYQkUBJ-znHIma0Xb_d4nfiOuzbDJYDAVEOgv7Lo63nqmUhvCDZTUnVFMZqOEE1qmgAOk85RUfi5IGLTVRdEJHqzlw4jnAjTIjLjwDc42nsdFHkLittVDjd_V6NmralYPxEiEEmymzVL8JxAfvg7P', 'width': 1131}, {'height': 1800, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104502708145722473527">rene schuster</a>'], 'photo_reference': 'Aap_uEBnXczrQ1SYi32Uld_ZkDKyKdZnV20jyK8yxFl-qnAF5TE6NDPeZnWGVlrPThj-TkuQTfSHF1GMGmWejukMe8MOWlE29Kkm_0RYMR-lG-o6xp9I0BtgUvzWTbUWEqz4LEBXfQW8UQl6b7tZfyl6urWmgupN77aN2aB-gQfZlMQVNWoq', 'width': 3131}, {'height': 608, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107314984843688174769">Fishers</a>'], 'photo_reference': 'Aap_uEBmJ1xFKAcwWzuqFl5k4En0nEYWwdiPVGJZWcDbAPG8bjhBtTAPWwSEguXRzHNTcmc_ykJRCGdR2oSfxfXgezEM5o1xEHf7q5wI4vNsRB8ZSgiS1dxdCnSloRaU0RNvqx2dsEWmWuXcv67vVa1aXPuQBcL5fqCxS9igBqMz5vGXXY-P', 'width': 1080}, {'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115725997811460177884">Damir Baranašić</a>'], 'photo_reference': 'Aap_uEBhcQqaMo1-e6G118Rs3ONOtD6k9_-qKtzfxW7BbUCrFFUxyWPM5sgw4JGJfi-r_5PxihtL_uLHASrn-2gQEGpk0VumbuEhz4BMbWnEf9hDy3H ...
# 020 7371 5555
# +44 20 7371 5555
# http://www.fisherslondon.co.uk/
# https://maps.google.com/?cid=321184255227157176
# Hoxton Fish House
# {'lat': Decimal('51.5290623'), 'lng': Decimal('-0.0837518')}
# ChIJATOZwqQcdkgRcTEtrPyLCH8
# {'address_components': [{'long_name': '59', 'short_name': '59', 'types': ['street_number']}, {'long_name': 'Pitfield Street', 'short_name': 'Pitfield St', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N1 6BU', 'short_name': 'N1 6BU', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">59 Pitfield Street</span>, <span class="locality">London</span> <span class="postal-code">N1 6BU</span>, <span class="country-name">UK</span>', 'business_status': 'OPERATIONAL', 'formatted_address': '59 Pitfield St, London N1 6BU, UK', 'formatted_phone_number': '020 7502 0014', 'geometry': {'location': {'lat': Decimal('51.5290623'), 'lng': Decimal('-0.0837518')}, 'viewport': {'northeast': {'lat': Decimal('51.5304048302915'), 'lng': Decimal('-0.08227676970849798')}, 'southwest': {'lat': Decimal('51.5277068697085'), 'lng': Decimal('-0.08497473029150204')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'international_phone_number': '+44 20 7502 0014', 'name': 'Hoxton Fish House', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 0, 'time': '2300'}, 'open': {'day': 0, 'time': '1200'}}, {'close': {'day': 1, 'time': '2300'}, 'open': {'day': 1, 'time': '1200'}}, {'close': {'day': 2, 'time': '2300'}, 'open': {'day': 2, 'time': '1200'}}, {'close': {'day': 3, 'time': '2300'}, 'open': {'day': 3, 'time': '1200'}}, {'close': {'day': 4, 'time': '2300'}, 'open': {'day': 4, 'time': '1200'}}, {'close': {'day': 6, 'time': '0000'}, 'open': {'day': 5, 'time': '1200'}}, {'close': {'day': 0, 'time': '0000'}, 'open': {'day': 6, 'time': '1200'}}], 'weekday_text': ['Monday: 12:00 – 11:00 PM', 'Tuesday: 12:00 – 11:00 PM', 'Wednesday: 12:00 – 11:00 PM', 'Thursday: 12:00 – 11:00 PM', 'Friday: 12:00 PM – 12:00 AM', 'Saturday: 12:00 PM – 12:00 AM', 'Sunday: 12:00 – 11:00 PM']}, 'photos': [{'height': 810, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109079519530128396887">Hoxton Fish House</a>'], 'photo_reference': 'Aap_uEDEuof4SGtgmBH3TIgvSZQqaz7BOqme9XNLjX41vCjZlollXOLSwsoNPq2hOOjyAF3rw03yfVMzW8y1lKHU6xLqRzPEU69Kb34LbIq7TT5GVi8fa7tjScvH0X-fQVzKZ77tbIzWNwlgAhRb8omQ1nEL78KQOhfYvbwamlo1vh3zU0Zy', 'width': 1440}, {'height': 604, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109079519530128396887">Hoxton Fish House</a>'], 'photo_reference': 'Aap_uEBBYjGtHXnwGcpcMis-YwMaONe9hS6hPgY3fPA5AWzwMXYizYhrw3NZPXyQscUaeqG1Xum-jhhsGvKTmS2K1ugKRCeohBu6w61B2PdSAh1ej324oWmgCLFefuaLMkxiEAX5UwBMu-JQHl8Cf1JV3VfadZ3nQNtl4v2rzLnvGFUVxfwP', 'width': 1074}, {'height': 2304, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101680086502944413718">Henk Groen</a>'], 'photo_reference': 'Aap_uECAJTYI2DtKlPiaeB6QpWOR3RG0MznstH-sVcLA0swOyC0POexig5bZ9SAaxrz3QxmDSWgtatE-a_TMyz3U_IKKQRhr5Mu1Xd7kHwSA5KWDeXx7jzTemV6V4-j2BS7J1Mmplv0J83hMa6MSPfKKZVWDm0kJip8Q2L6IUpi6Sgjars1Q', 'width': 4608}, {'height': 1577, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109079519530128396887">Hoxton Fish House</a>'], 'photo_reference': 'Aap_uEAfHm3uDY8KYceCiQWQPkugICNG-8YmurCEBloyuFjM0Z_FA-dY1r8z5s3fzZO-XxL1rXr4fRBYn-EwCywsjU_L777lcRWukj8oAKdOxqWLLBUJ02U1D18Xz2sxQhfMVxPRpiM6YFABXmPYTGpZmGPqpuTdpXgtzrLZUceRsqDvsMC9', 'width': 1577}, {'height': 3999, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109079519530128396887">Hoxton Fish House</a>'], 'photo_reference': 'Aap_uEDL4FTeTtsKQgkJb9IgXXHdRp915fD2e6Vdm2X0kIhsJuPxf1r6e4fSACaK-C81Xq9ZY_pss4Ek ...
# 020 7502 0014
# +44 20 7502 0014
# https://hoxtonfishhouse.business.site/?utm_source=gmb&utm_medium=referral
# https://maps.google.com/?cid=9153720159967195505
# Golden Union
# {'lat': Decimal('51.5153926'), 'lng': Decimal('-0.1375941')}
# ChIJLZnILisbdkgR1ok3oOdfcl4
# {'address_components': [{'long_name': '38', 'short_name': '38', 'types': ['street_number']}, {'long_name': 'Poland Street', 'short_name': 'Poland St', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1F 7LY', 'short_name': 'W1F 7LY', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">38 Poland Street</span>, <span class="locality">London</span> <span class="postal-code">W1F 7LY</span>, <span class="country-name">UK</span>', 'business_status': 'OPERATIONAL', 'formatted_address': '38 Poland St, London W1F 7LY, UK', 'formatted_phone_number': '020 7434 1933', 'geometry': {'location': {'lat': Decimal('51.5153926'), 'lng': Decimal('-0.1375941')}, 'viewport': {'northeast': {'lat': Decimal('51.5168256802915'), 'lng': Decimal('-0.136593819708498')}, 'southwest': {'lat': Decimal('51.5141277197085'), 'lng': Decimal('-0.139291780291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'international_phone_number': '+44 20 7434 1933', 'name': 'Golden Union', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 2, 'time': '2100'}, 'open': {'day': 2, 'time': '1130'}}, {'close': {'day': 3, 'time': '2100'}, 'open': {'day': 3, 'time': '1130'}}, {'close': {'day': 4, 'time': '2100'}, 'open': {'day': 4, 'time': '1130'}}, {'close': {'day': 5, 'time': '2100'}, 'open': {'day': 5, 'time': '1130'}}, {'close': {'day': 6, 'time': '2100'}, 'open': {'day': 6, 'time': '1130'}}], 'weekday_text': ['Monday: Closed', 'Tuesday: 11:30 AM – 9:00 PM', 'Wednesday: 11:30 AM – 9:00 PM', 'Thursday: 11:30 AM – 9:00 PM', 'Friday: 11:30 AM – 9:00 PM', 'Saturday: 11:30 AM – 9:00 PM', 'Sunday: Closed']}, 'photos': [{'height': 2448, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/
 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114306003644934410016">Fish and Ships of Globe Town</a>'], 'photo_reference': 'Aap_uECKUrwesIUiJtEyrLJnf-kJXNbsSy0f4d1cdDrdkqeaEHDOWpmkmW4-0DyIRe9ZOYPssFqxF1r52tRhOqDbdyh6m87BA8qIxVIX_uujnHq1m97O2N2wc-UG9nB2PeCztTuVIelsph3nX63hjuf-Hs1ctn9G_rvwz3_dQvWm4e8fVMG7', 'width': 2436}, {'height': 4032 ...
# 020 7998 4080
# +44 20 7998 4080
# None
# https://maps.google.com/?cid=11701925217346582971
# The Crown Fish & Chip Bar
# {'lat': Decimal('51.5335486'), 'lng': Decimal('-0.1093277')}
# ChIJM3FeUkIbdkgR8rvVJOFqDEY
# {'address_components': [{'long_name': '20', 'short_name': '20', 'types': ['street_number']}, {'long_name': 'Chapel Market', 'short_name': 'Chapel Market', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N1 9EZ', 'short_name': 'N1 9EZ', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">20 Chapel Market</span>, <span class="locality">London</span> <span class="postal-code">N1 9EZ</span>, <span class="country-name">UK</span>', 'business_status': 'OPERATIONAL', 'formatted_address': '20 Chapel Market, London N1 9EZ, UK', 'formatted_phone_number': '020 7278 0812', 'geometry': {'location': {'lat': Decimal('51.5335543'), 'lng': Decimal('-0.1093253')}, 'viewport': {'northeast': {'lat': Decimal('51.5348613802915'), 'lng': Decimal('-0.107979619708498')}, 'southwest': {'lat': Decimal('51.5321634197085'), 'lng': Decimal('-0.110677580291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'international_phone_number': '+44 20 7278 0812', 'name': 'The Crown Fish & Chip Bar', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 0, 'time': '1930'}, 'open': {'day': 0, 'time': '1100'}}, {'close': {'day': 1, 'time': '2100'}, 'open': {'day': 1, 'time': '1030'}}, {'close': {'day': 2, 'time': '2100'}, 'open': {'day': 2, 'time': '1030'}}, {'close': {'day': 3, 'time': '2100'}, 'open': {'day': 3, 'time': '1030'}}, {'close': {'day': 4, 'time': '2100'}, 'open': {'day': 4, 'time': '1030'}}, {'close': {'day': 5, 'time': '2100'}, 'open': {'day': 5, 'time': '1030'}}, {'close': {'day': 6, 'time': '2100'}, 'open': {'day': 6, 'time': '1030'}}], 'weekday_text': ['Monday: 10:30 AM – 9:00 PM', 'Tuesday: 10:30 AM – 9:00 PM', 'Wednesday: 10:30 AM – 9:00 PM', 'Thursday: 10:30 AM – 9:00 PM', 'Friday: 10:30 AM – 9:00 PM', 'Saturday: 10:30 AM – 9:00 PM', 'Sunday: 11:00 AM – 7:30 PM']}, 'photos': [{'height': 642, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101984288879877920135">Dear John</a>'], 'photo_reference': 'Aap_uEDiXDbgomHFqQBZ6Xl1U4CpCJM3jT_vTKWRZZ602TzKZkqryY7G0SoQDcQ4bfUDXB_d4HGKQ84aDrNpAY0mSquIh3Y5tHQSFaRy7GOq-W_fhKwj0Lsjgy_tRZF3s-2GKRvKFBtwP9fyjRV2Q7TpsK-rta8ansKzJMwGyz1XTaJqd2hf', 'width': 960}, {'height': 440, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110848838014002868939">We are OCUS - 3</a>'], 'photo_reference': 'Aap_uEDhXXdJMwhS9zU2lA6coQgWU173zIgwO6acg9_Sm08NHSZmh7BIEWZ-d-d9E64vZmqARxFSqn4uqLSrVCZBu_eXK061gUVLeVXZNhgxxmsI5M7okwJ-8ub8QLwmBy73F7PkCdit8o1hbslz1sv0q2qicOF-_TgGFZbuVs34wbWpWAvm', 'width': 550}, {'height': 642, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101984288879877920135">Dear John</a>'], 'photo_reference': 'Aap_uEBsmEDYuI__pJvVAkaU6DBPVPTjfbAjtJPFrjtSdqa7hn_geo2iukjMRD9a4sge_QqvYp4QNVSQkadvfJi4yGkuc2neLCpI2YNU49Cp8lor8gZL95plAHnJXGxCanHadOP7xzBLzxOCHcKcrASHY9C4ABcTYCLZgmlCFl-O07e6CVM7', 'width': 960}, {'height': 4032, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106835876051530075104">Kieran Marrett-munro</a>'], 'photo_reference': 'Aap_uED-MLImYnSSrX2CGEnS5q4kf-vSE6mNrdP-zXeGx2hs3LYO1AdGsCHW2dgJzDd4-ZURRNOGEpgVakmQP1Ep2C7EmWQoyuSOYgWxtWYD8CPQxG0uPPwWvqswwolgk1QODSpDXW7dU-h8RlBmmNrVOm4Ua0JvNMg70_yNNcaC3T5G4sHH', 'width': 3024}, {'height': 2272, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117322094672914870374">Ellie - Busy in London</a>'], 'photo_reference': 'Aap_uEChRnVzA452TLCpc91iBxaqul4I7RTIcFvSKpOnlwkZ9brW3oWlADrPJM-j49_wBs57lvG ...
# 020 7278 0812
# +44 20 7278 0812
# None
# https://maps.google.com/?cid=5047526797593656306
# The Laughing Halibut
# {'lat': Decimal('51.4966523'), 'lng': Decimal('-0.1338014')}
# ChIJ_1eRNNwEdkgRu2jDWONeeSE
# {'address_components': [{'long_name': '38', 'short_name': '38', 'types': ['street_number']}, {'long_name': 'Strutton Ground', 'short_name': 'Strutton Ground', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW1P 2HR', 'short_name': 'SW1P 2HR', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">38 Strutton Ground</span>, <span class="locality">London</span> <span class="postal-code">SW1P 2HR</span>, <span class="country-name">UK</span>', 'business_status': 'OPERATIONAL', 'formatted_address': '38 Strutton Ground, London SW1P 2HR, UK', 'formatted_phone_number': '020 7799 2844', 'geometry': {'location': {'lat': Decimal('51.4966523'), 'lng': Decimal('-0.1338014')}, 'viewport': {'northeast': {'lat': Decimal('51.4979573302915'), 'lng': Decimal('-0.132396719708498')}, 'southwest': {'lat': Decimal('51.4952593697085'), 'lng': Decimal('-0.135094680291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'international_phone_number': '+44 20 7799 2844', 'name': 'The Laughing Halibut', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 1, 'time': '2000'}, 'open': {'day': 1, 'time': '1100'}}, {'close': {'day': 2, 'time': '2000'}, 'open': {'day': 2, 'time': '1100'}}, {'close': {'day': 3, 'time': '2000'}, 'open': {'day': 3, 'time': '1100'}}, {'close': {'day': 4, 'time': '2000'}, 'open': {'day': 4, 'time': '1100'}}, {'close': {'day': 5, 'time': '2000'}, 'open': {'day': 5, 'time': '1100'}}, {'close': {'day': 6, 'time': '1600'}, 'open': {'day': 6, 'time': '1100'}}], 'weekday_text': ['Monday: 11:00 AM – 8:00 PM', 'Tuesday: 11:00 AM – 8:00 PM', 'Wednesday: 11:00 AM – 8:00 PM', 'Thursday: 11:00 AM – 8:00 PM', 'Friday: 11:00 AM – 8:00 PM', 'Saturday: 11:00 AM – 4:00 PM', 'Sunday: Closed']}, 'photos': [{'height': 3008, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/
 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105554190460897158302">Paul Athe ...
# 020 7723 2384
# +44 20 7723 2384
# None
# https://maps.google.com/?cid=10642667236486522485
# Blue Anchor Fish & Chips
# {'lat': Decimal('51.492638'), 'lng': Decimal('-0.06274589999999999')}
# ChIJS0F3QBYDdkgRmeqKny44nqc
# ...
# 020 7387 6923
# +44 20 7387 6923
# https://chriss-fish-bar-fish-and-chips-takeaway.business.site/?utm_source=gmb&utm_medium=referral
# https://maps.google.com/?cid=5378655138362465430
# The Fryer's Delight
# {'lat': Decimal('51.52037319999999'), 'lng': Decimal('-0.1173074')}
# ChIJbdMAAzYbdkgRICjp99400zA
# {'address_components': [{'long_name': '19', 'short_name': '19', 'types': ['street_number']}, {'long_name': 'Theobalds Road', 'short_name': 'Theobalds Rd', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'WC1X 8SL', 'short_name': 'WC1X 8SL', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">19 Theobalds Road</span>, <span class="locality">London</span> <span class="postal-code">WC1X 8SL</span>, <span class="country-name">UK</span>', 'business_status': 'OPERATIONAL', 'formatted_address': '19 Theobalds Rd, London WC1X 8SL, UK', 'formatted_phone_number': '020 7405 4114', 'geometry': {'location': {'lat': Decimal('51.520379'), 'lng': Decimal('-0.1173112')}, 'viewport': {'northeast': {'lat': Decimal('51.5217737302915'), 'lng': Decimal('-0.115992569708498')}, 'southwest': {'lat': Decimal('51.5190757697085'), 'lng': Decimal('-0.118690530291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'international_phone_number': '+44 20 7405 4114', 'name': "The Fryer's Delight", 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 1, 'time': '2200'}, 'open': {'day': 1, 'time': '1200'}}, {'close': {'day': 2, 'time': '2200'}, 'open': {'day': 2, 'time': '1200'}}, {'close': {'day': 3, 'time': '2200'}, 'open': {'day': 3, 'time': '1200'}}, {'close': {'day': 4, 'time': '2200'}, 'open': {'day': 4, 'time': '1200'}}, {'close': {'day': 5, 'time': '2200'}, 'open': {'day': 5, 'time': '1200'}}, {'close': {'day': 6, 'time': '2200'}, 'open': {'day': 6, 'time': '1200'}}], 'weekday_text': ['Monday: 12:00 – 10:00 PM', 'Tuesday: 12:00 – 10:00 PM', 'Wednesday: 12:00 – 10:00 PM', 'Thursday: 12:00 – 10:00 PM', 'Friday: 12:00 – 10:00 PM', 'Saturday: 12:00 – 10:00 PM', 'Sunday: Closed']}, 'photos': [{'height': 645, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111385683566897851257">The Fryer&#39;s Delight</a>'], 'photo_reference': 'Aap_uEDCa7un6m9AOBbpQ1P8mUckh-KHA8YwK9mrNg3oadvA3AfC_Mrn_vGSl44hNUR_RS6AM-JYEAvAEmetEcA8j8gUtO0zkJsphrFqhjcsAPm1T4dbHDN98HKjW7KOgW-h8sKMIog_MQOXoLHObKaoDlS5pnAVMMz63OD7Kqq1J9AAVyrV', 'width': 916}, {'height': 3456, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115462569130839701348">Shankar Kadam</a>'], 'photo_reference': 'Aap_uEA7c0TVVt-vIlGX0gFCXv-zr9qu9XS_nOXTZjSAs834aY3ODVWTZqmZqhZj30ucIC7wzNbFoekgaAQDEY6QV8Y9XoSsQbI-gnWK2ge_kH0Wjri8YtteU_h5efvdmuAeyg7HRbLBN650eUBHBfFvGwPnBIZEhlb9svlwaY7GqQFMcLoN', 'width': 4608}, {'height': 2250, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102341559018174608614">Matteo Naccari</a>'], 'photo_reference': 'Aap_uEANtUeavcjXSdyv1g-1y9I3_JH4sh3nPOtdHAfZuHr3wi5wPzBRDVMEo7mU6i-h-EPUOC897eAq2NTbYab1T6Q0tg_q0k2XQjTCdyxql8EW6uVGJbYv6h0yxRx0mtMycqVKjwk7Qfj3X7X5bPXpLkHX-kCFkJURh8UIbWQTeawYTq8V', 'width': 4000}, {'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102095024849368821372">Matthew Crowther</a>'], 'photo_reference': 'Aap_uECz4rRcaCDwXK5WxmNs-iDVEQ9OwOXjxYnRGTKtAcBiAuXDS99SAO2OHNO1ma8vLK1FNDt_zzsTfG0-0LGZAqq9sHC-w7MxmpJca7y-sFKhe5ujl0ulAmEVKF5ajZ5TGGOw9nasJVYgouDd_6OrOF5eqCCb1sGmSYzZyZjo-bziG9qu', 'width': 4032}, {'height': 2878, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106940218410473080523">Mr Wrong</a>'], 'photo_reference': 'Aap_uEBZlN531jnzLS9tRbqiBRXNhR9Y217psfBbsHB_UDGELNZ0tq3muEvia1jibSB9qJmBiFzi_05JBor9dmt4a2xg9BD7L90nEJdJQXSKVnzdDOOGThAscR7_itn1Lm7KZ94FMkJKtIfQcHOtgL_E651xjSEKEybTfOUtj8 ...
# 020 7405 4114
# +44 20 7405 4114
# https://www.facebook.com/fishandchips.co.uk/
# https://maps.google.com/?cid=3518213866153125920
# Masters Superfish
# {'lat': Decimal('51.5005213'), 'lng': Decimal('-0.1076922')}
# ChIJjTLFErsEdkgRz-x8WQlZaK0
# {'address_components': [{'long_name': '191', 'short_name': '191', 'types': ['street_number']}, {'long_name': 'Waterloo Road', 'short_name': 'Waterloo Rd', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SE1 8UX', 'short_name': 'SE1 8UX', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">191 Waterloo Road</span>, <span class="locality">London</span> <span class="postal-code">SE1 8UX</span>, <span class="country-name">UK</span>', 'business_status': 'OPERATIONAL', 'formatted_address': '191 Waterloo Rd, London SE1 8UX, UK', 'formatted_phone_number': '020 7928 6924', 'geometry': {'location': {'lat': Decimal('51.500519'), 'lng': Decimal('-0.1077058')}, 'viewport': {'northeast': {'lat': Decimal('51.5018459302915'), 'lng': Decimal('-0.106454669708498')}, 'southwest': {'lat': Decimal('51.4991479697085'), 'lng': Decimal('-0.109152630291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'international_phone_number': '+44 20 7928 6924', 'name': 'Masters Superfish', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 2, 'time': '2200'}, 'open': {'day': 2, 'time': '1630'}}, {'close': {'day': 3, 'time': '2200'}, 'open': {'day': 3, 'time': '1630'}}, {'close': {'day': 4, 'time': '2200'}, 'open': {'day': 4, 'time': '1630'}}, {'close': {'day': 5, 'time': '1500'}, 'open': {'day': 5, 'time': '1200'}}, {'close': {'day': 5, 'time': '2200'}, 'open': {'day': 5, 'time': '1630'}}, {'close': {'day': 6, 'time': '2200'}, 'open': {'day': 6, 'time': '1630'}}], 'weekday_text': ['Monday: Closed', 'Tuesday: 4:30 – 10:00 PM', 'Wednesday: 4:30 – 10:00 PM', 'Thursday: 4:30 – 10:00 PM', 'Friday: 12:00 – 3:00 PM, 4:30 – 10:00 PM', 'Saturday: 4:30 – 10:00 PM', 'Sunday: Closed']}, 'photos': [{'height': 540, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104286443772558357661">Masters Superfish</a>'], 'photo_reference': 'Aap_uEAHCMMeT5p3pF8gTZs-KFK-RuZ2-HMzZK-np1mfGM8s2kgT_xmMqDBt4vwR0Qcop-2mVNAhCSEvBKUeE48ZEcOB3CgjOaTypzyzsrXhr1vuyHpfgWIp2JISlYpbWoFoFCb7kowwTBbgUZS1UcqgCPdAf-YH_mKMC4v4hu2yR9n2cBgI', 'width': 960}, {'height': 1600, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104286443772558357661">Masters Superfish</a>'], 'photo_reference': 'Aap_uECI-1HSV1I3sKJXXbdbp9ydL5kLkufd4m6vj1rvFLHO_zFExKfs7sPrvACmNfZGnP7Y3bh1jj6xZcNcyX_-VnTtrl6jTF6XG1o8CCzfJ4lk1ZMgU_7jxmn_gcdvw0hdJzlHQ5Fc_gfV7nzdLysOalCK3rMfI3HGiOu078hufOL8Zsy4', 'width': 1200}, {'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104169661427729493227">Tommaso Baldovino</a>'], 'photo_reference': 'Aap_uECHGDiN3GnX4JgekpWYZ_5UHSyhapRyqrRcekS51y9PZ6NbJuL6CzuwY5N42VKUv5UHOAeeBbuFyhliuwyd69ENOWmFxDJ8AAcDrH7EVgvS0nHFuUE5WIbcrBkSP2YsgiYknVnin7itVe4rBCDuTElEFOiXVcfE2PL8uQnDLskWda-F', 'width': 4032}, {'height': 2267, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105009832214699042429">Ray Osburn</a>'], 'photo_reference': 'Aap_uECFhsulvdCdafO-FYvsY2sMJP2EfJ_StyVaDN181Uabp1HEUnBdZbElhfrKa1j22N8JdkPgxL7NcT_U121eQXy718r426yI4GqL6rHPngTnk9rvovbU48_7gXgup0lyMyePuyWW3mbyCeVgCLipFDZqcQAecEhvshyv3w5dRBXEanwa', 'width': 4031}, {'height': 2736, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114052548948973836262">Rudolf Frint</a>'], 'photo_reference': 'Aap_uEDvG8rSDTShX1BLxC3vri5jcrzcETjTqKft0wtEsuPYQWCtElQNh1Uge7ht2iq7fDsUisHhoC7TgpWNsvGh03h2gpKzCmrjuzoPXDtsBz8D91sJ1tp5KbT3qHi_8sJFI0pDJYy1mjNxp_2ZRciJoXCUV2ixnImnDhBAeZkELL3 ...
# 020 7928 6924
# +44 20 7928 6924
# https://masterssuperfish.business.site/
# https://maps.google.com/?cid=12495335062830378191
# Belmont Bay Fish & Chips
# {'lat': Decimal('51.6012371'), 'lng': Decimal('-0.3189255')}
# ChIJuTtuK3gUdkgR8cAt5PXhkgE
# {'address_components': [{'long_name': '500', 'short_name': '500', 'types': ['street_number']}, {'long_name': 'Kenton Lane', 'short_name': 'Kenton Ln', 'types': ['route']}, {'long_name': 'Stanmore', 'short_name': 'Stanmore', 'types': ['locality', 'political']}, {'long_name': 'Harrow', 'short_name': 'Harrow', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'HA3 8RD', 'short_name': 'HA3 8RD', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">500 Kenton Lane</span>, <span class="extended-address">Stanmore</span>, <span class="locality">Harrow</span> <span class="postal-code">HA3 8RD</span>, <span class="country-name">UK</span>', 'business_status': 'OPERATIONAL', 'formatted_address': '500 Kenton Ln, Stanmore, Harrow HA3 8RD, UK', 'formatted_phone_number': '020 8907 0710', 'geometry': {'location': {'lat': Decimal('51.6012333'), 'lng': Decimal('-0.3189236')}, 'viewport': {'northeast': {'lat': Decimal('51.60253228029151'), 'lng': Decimal('-0.317549069708498')}, 'southwest': {'lat': Decimal('51.59983431970851'), 'lng': Decimal('-0.3202470302915021')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'international_phone_number': '+44 20 8907 0710', 'name': 'Belmont Bay Fish & Chips', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 1, 'time': '2200'}, 'open': {'day': 1, 'time': '1130'}}, {'close': {'day': 2, 'time': '2200'}, 'open': {'day': 2, 'time': '1130'}}, {'close': {'day': 3, 'time': '2200'}, 'open': {'day': 3, 'time': '1130'}}, {'close': {'day': 4, 'time': '2200'}, 'open': {'day': 4, 'time': '1130'}}, {'close': {'day': 5, 'time': '2200'}, 'open': {'day': 5, 'time': '1130'}}, {'close': {'day': 6, 'time': '2200'}, 'open': {'day': 6, 'time': '1130'}}], 'weekday_text': ['Monday: 11:30 AM – 10:00 PM', 'Tuesday: 11:30 AM – 10:00 PM', 'Wednesday: 11:30 AM – 10:00 PM', 'Thursday: 11:30 AM – 10:00 PM', 'Friday: 11:30 AM – 10:00 PM', 'Saturday: 11:30 AM – 10:00 PM', 'Sunday: Closed']}, 'photos': [{'height': 1494, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109824788473939315167">Belmont Bay Fish &amp; Chips</a>'], 'photo_reference': 'Aap_uEBfoRTIcvgm0GY_TY9sTwVXTu6Ykc8yKLjugr23Rlo4AJi5ijjrQMK_3fszw_6h04aY7brpzoTTX58qPSunZOgsrQ4Mw3RiI9bGTgWxkSBa9QDJkE-Qspck1R3wOWwcpFf9H1KlwGJGyGfzhYwGpV1bTHNNIhoiea4lAZSdJUUhSiZ-', 'width': 2656}, {'height': 1494, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109824788473939315167">Belmont Bay Fish &amp; Chips</a>'], 'photo_reference': 'Aap_uED9iNMhxpjNOvHcihLY0JsgxNLVdCrREJyrUPM2JIQFBuVgklPa06a_lrfpR39Qt8DvCNddbtV8CAF5HbcaoIX1JNlME37s1ZXSfBThkBugStAenqluSz6DaSAZzK6iVtvEIEv2NmVijzWCBqDCzYCpGN8YEG4lBVSFQ9fQMSNX0TRX', 'width': 2656}, {'height': 1494, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109824788473939315167">Belmont Bay Fish &amp; Chips</a>'], 'photo_reference': 'Aap_uEB01s61jkxt46Up0E3q5bvLHtRTjjeEpeyZ3oF-8QsBwi8rGTH5329pF0CKKS3kPyNjRL3vSUvPUnT7-Y1ostMTd7bhdUHUIro7g2PbCbajNp4XMvmhpSr9bUqzxTYXyF9nWP0uo7l4CtWMz_ixZxmHluiOTuuqmTHFjSgvxf_LGewg', 'width': 2656}, {'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110234695533896785088">Nirvana Dutt</a>'], 'photo_reference': 'Aap_uEAR3qBLn0lyH5-vw04UZddST2SSV-UmX7GCt09obczydLGkxPKN-V_O0mqrImnvah4WgPVe1j9l0dDzaB9GjXFso_sa5TP7SVOuRnU8QLRG9Uak4OliC8WisZCeDIbdiaZolwfypDxaPMrkXfuy-T3Jh4xrVBdw4HydPZvl9b3t2a1l', 'width': 4032}, {'height': 2268, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103801915398192688305">Felix Gan</a ...
# 020 8907 0710
# +44 20 8907 0710
# http://belmont-bay.co.uk/
# https://maps.google.com/?cid=113401386849124593
# ---------------------------------------------------------------------------
# GooglePlacesError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googleplaces\__init__.py in _generate_lat_lng_string(self, lat_lng, location)
#     589             return '%(lat)s,%(lng)s' % (lat_lng if lat_lng is not None
# --> 590                     else geocode_location(location=location, api_key=self.api_key))
#     591         except GooglePlacesError as e:
#
# ~\Anaconda3\lib\site-packages\googleplaces\__init__.py in geocode_location(location, sensor, api_key)
#     122                         location)
# --> 123         raise GooglePlacesError(error_detail)
#     124     return geo_response['results'][0]['geometry']['location']
#
# GooglePlacesError: Lat/Lng for location 'None' can't be determined.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-916a1fe6eed2> in <module>
#      48 # Are there any additional pages of results?
#      49 if query_result.has_next_page_token:
# ---> 50     query_result_next_page = google_places.nearby_search(
#      51             pagetoken=query_result.next_page_token)
#
# ~\Anaconda3\lib\site-packages\googleplaces\__init__.py in nearby_search(self, language, keyword, location, lat_lng, name, radius, rankby, sensor, type, types, pagetoken)
#     279         radius = (radius if radius <= GooglePlaces.MAXIMUM_SEARCH_RADIUS
#     280                   else GooglePlaces.MAXIMUM_SEARCH_RADIUS)
# --> 281         lat_lng_str = self._generate_lat_lng_string(lat_lng, location)
#     282         self._request_params = {'location': lat_lng_str}
#     283         if rankby == 'prominence':
#
# ~\Anaconda3\lib\site-packages\googleplaces\__init__.py in _generate_lat_lng_string(self, lat_lng, location)
#     590                     else geocode_location(location=location, api_key=self.api_key))
#     591         except GooglePlacesError as e:
# --> 592             raise ValueError(
#     593                 'lat_lng must be a dict with the keys, \'lat\' and \'lng\'. Cause: %s' % str(e))
#     594
#
# ValueError: lat_lng must be a dict with the keys, 'lat' and 'lng'. Cause: Lat/Lng for location 'None' can't be determined.

# %%
# Adding and deleting a place
try:
    added_place = google_places.add_place(name='Mom and Pop local store',
            lat_lng={'lat': 51.501984, 'lng': -0.141792},
            accuracy=100,
            types=types.TYPE_HOME_GOODS_STORE,
            language=lang.ENGLISH_GREAT_BRITAIN)
    print added_place.place_id # The Google Places identifier - Important!
    print added_place.id

    # Delete the place that you've just added.
    google_places.delete_place(added_place.place_id)
except GooglePlacesError as error_detail:
    # You've passed in parameter values that the Places API doesn't like..
    print error_detail
